# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\andy_\OneDrive\Desktop\Python Training Files\284_618_bundle_archive\vgsales.csv')
#df.set_index('Rank', inplace=True)
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# #### Question 1: Which publisher has the highest total sales? Show the top 10 publisher by sales on a graph

# %%
df1 = df.groupby('Publisher').sum()
#df1[df1['Publisher'] == 'Nintendo']
df1 = df1.sort_values(by='Global_Sales', ascending=False)
df1.head(10)
# Out:
#                                  Rank       Year  NA_Sales  EU_Sales  \
# Publisher
# Nintendo                      2714164  1394666.0    816.87    418.74
# Electronic Arts               7140412  2686562.0    595.07    371.27
# Activision                    6368325  1938979.0    429.70    215.53
# Sony Computer Entertainment   4105604  1367034.0    265.22    187.72
# Ubisoft                       6964728  1843194.0    253.43    163.32
# Take-Two Interactive          2622275   827344.0    220.49    118.14
# THQ                           4772674  1428311.0    208.77     94.73
# Konami Digital Entertainment  7331538  1650392.0     92.16     69.69
# Sega                          5070801  1267395.0    109.40     82.00
# Namco Bandai Games            8741157  1863670.0     69.52     42.63
#
#                               JP_Sales  Other_Sales  Global_Sales
# Publisher
# Nintendo                        455.42        95.33       1786.56
# ...

# %%
df2 = df1.head(10)
df2
# Out:
#                                  Rank       Year  NA_Sales  EU_Sales  \
# Publisher
# Nintendo                      2714164  1394666.0    816.87    418.74
# Electronic Arts               7140412  2686562.0    595.07    371.27
# Activision                    6368325  1938979.0    429.70    215.53
# Sony Computer Entertainment   4105604  1367034.0    265.22    187.72
# Ubisoft                       6964728  1843194.0    253.43    163.32
# Take-Two Interactive          2622275   827344.0    220.49    118.14
# THQ                           4772674  1428311.0    208.77     94.73
# Konami Digital Entertainment  7331538  1650392.0     92.16     69.69
# Sega                          5070801  1267395.0    109.40     82.00
# Namco Bandai Games            8741157  1863670.0     69.52     42.63
#
#                               JP_Sales  Other_Sales  Global_Sales
# Publisher
# Nintendo                        455.42        95.33       1786.56
# ...

# %%
#Put results on to grpah
df2.reset_index(inplace= True)
df2
# Out:
#                       Publisher     Rank       Year  NA_Sales  EU_Sales  \
# 0                      Nintendo  2714164  1394666.0    816.87    418.74
# 1               Electronic Arts  7140412  2686562.0    595.07    371.27
# 2                    Activision  6368325  1938979.0    429.70    215.53
# 3   Sony Computer Entertainment  4105604  1367034.0    265.22    187.72
# 4                       Ubisoft  6964728  1843194.0    253.43    163.32
# 5          Take-Two Interactive  2622275   827344.0    220.49    118.14
# 6                           THQ  4772674  1428311.0    208.77     94.73
# 7  Konami Digital Entertainment  7331538  1650392.0     92.16     69.69
# 8                          Sega  5070801  1267395.0    109.40     82.00
# 9            Namco Bandai Games  8741157  1863670.0     69.52     42.63
#
#    JP_Sales  Other_Sales  Global_Sales
# 0    455.42        95.33       1786.56
# 1     14.04       129.77       1110.32
# 2      6.54        75.34        727.46
# ...

# %%
plt.bar(df2['Publisher'], df2['Global_Sales'])
plt.xticks(rotation='vertical', size=10)
plt.title('Publisher by Global Sales')
plt.xlabel('Publishers')
plt.ylabel('Global sales (millions)')
plt.grid()
plt.show()

# %% [markdown]
# #### Question 2: What is the total sales by region?

# %%
data = {'Region' : ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales'],
            'Total Sales': [df1['NA_Sales'].sum(), df1['EU_Sales'].sum(), df1['JP_Sales'].sum(), df1['Other_Sales'].sum()]}
df_region = pd.DataFrame(data, columns=['Region', 'Total Sales'])
df_region
# Out:
#         Region  Total Sales
# 0     NA_Sales      4384.41
# 1     EU_Sales      2429.45
# 2     JP_Sales      1290.09
# 3  Other_Sales       797.08

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales'
sizes = df_region['Total Sales']
explode = (0, 0.1, 0, 0)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=60)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# #### Question 3: Rank the Genre by sales from highest sales to lowest

# %%
df_genre = df.groupby('Genre').sum()
df_genre.drop(['Rank', 'Year','NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales'], axis = 1, inplace=True)
df_genre
df_genre.sort_values(by='Global_Sales', ascending = False)
# Out:
#               Global_Sales
# Genre
# Action             1751.18
# Sports             1330.93
# Shooter            1037.37
# Role-Playing        927.37
# Platform            831.37
# Misc                809.96
# Racing              732.04
# Fighting            448.91
# Simulation          392.20
# Puzzle              244.95
# Adventure           239.04
# Strategy            175.12

# %% [markdown]
# #### Question 4: Which publisher has the most sales for each Genre?

# %%
df4 = df.sort_values('Global_Sales', ascending = False).drop_duplicates(['Genre'])
df4
# Out:
#      Rank                                Name Platform    Year         Genre  \
# 0       1                          Wii Sports      Wii  2006.0        Sports
# 1       2                   Super Mario Bros.      NES  1985.0      Platform
# 2       3                      Mario Kart Wii      Wii  2008.0        Racing
# 4       5            Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# 5       6                              Tetris       GB  1989.0        Puzzle
# 7       8                            Wii Play      Wii  2006.0          Misc
# 9      10                           Duck Hunt      NES  1984.0       Shooter
# 10     11                          Nintendogs       DS  2005.0    Simulation
# 16     17                  Grand Theft Auto V      PS3  2013.0        Action
# 39     40             Super Smash Bros. Brawl      Wii  2008.0      Fighting
# 50     51  Super Mario Land 2: 6 Golden Coins       GB  1992.0     Adventure
# ...

# %% [markdown]
# #### Question 5: What is the highest selling game for the top 10 publishers?

# %%
df5 = df.sort_values('Global_Sales', ascending = False).drop_duplicates(['Publisher'])
df5.head(10)
# Out:
#     Rank                                Name Platform    Year         Genre  \
# 0      1                          Wii Sports      Wii  2006.0        Sports
# 15    16                  Kinect Adventures!     X360  2010.0          Misc
# 16    17                  Grand Theft Auto V      PS3  2013.0        Action
# 28    29              Gran Turismo 3: A-Spec      PS2  2001.0        Racing
# 29    30      Call of Duty: Modern Warfare 3     X360  2011.0       Shooter
# 60    61                        Just Dance 3      Wii  2011.0          Misc
# 75    76         The Elder Scrolls V: Skyrim     X360  2011.0  Role-Playing
# 77    78                             FIFA 16      PS4  2015.0        Sports
# 85    86  Mario & Sonic at the Olympic Games      Wii  2007.0        Sports
# 87    88                  Final Fantasy VIII       PS  1999.0  Role-Playing
#
#                       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %% [markdown]
# #### Question 6: Which year had the greatest number of sales?

# %%
df6 = df.groupby(['Year'], as_index = False).sum()
df6
# Out:
#       Year      Rank  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0   1980.0     29826     10.59      0.67      0.00         0.12         11.38
# 1   1981.0    190488     33.40      1.96      0.00         0.32         35.77
# 2   1982.0    149186     26.92      1.65      0.00         0.31         28.86
# 3   1983.0     56759      7.76      0.80      8.10         0.14         16.79
# 4   1984.0     22911     33.28      2.10     14.27         0.70         50.36
# 5   1985.0     55505     33.73      4.74     14.56         0.92         53.94
# 6   1986.0     35986     12.50      2.84     19.81         1.93         37.07
# 7   1987.0     54701      8.46      1.41     11.63         0.20         21.74
# 8   1988.0     37181     23.87      6.59     15.76         0.99         47.22
# 9   1989.0     40156     45.15      8.44     18.36         1.50         73.45
# 10  1990.0     25106     25.46      7.63     14.88         1.40         49.39
# ...

# %%
plt.bar(df['Year'], df['Global_Sales'])
plt.xlabel('Year')
plt.ylabel('Global Sales (millions)')
plt.show()

# %% [markdown]
# #### Question 7: What is the total Global sales for each year and what percentage of sales did the highest selling game account for in each year?
